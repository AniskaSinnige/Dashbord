# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (1.1.0)
# Requirement already satisfied: astor in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (0.8.1)
# Requirement already satisfied: base58 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: attrs in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (21.2.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: packaging in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (21.0)
# Requirement already satisfied: toml in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (3.1.24)
# Requirement already satisfied: tornado>=5.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (3.19.1)
# Requirement already satisfied: numpy in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (1.20.3)
# Requirement already satisfied: tzlocal in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (4.1)
# Requirement already satisfied: cachetools>=4.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (4.2.4)
# Requirement already satisfied: pyarrow in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (1.3.3)
# Requirement already satisfied: requests in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: validators in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: python-dateutil in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: blinker in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (1.4)
# Requirement already satisfied: watchdog in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: altair>=3.2.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: entrypoints in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: jinja2 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from altair>=3.2.0->streamlit) (3.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from gitpython!=3.1.19->streamlit) (3.10.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.0)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (6.2.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.0.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.27.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: colorama in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.20)
# Requirement already satisfied: backcall in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: decorator in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (58.0.4)
# Requirement already satisfied: pygments in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.10.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (228)
# Requirement already satisfied: six>=1.11.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.3)
# Requirement already satisfied: argon2-cffi in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.11.0)
# Requirement already satisfied: nbconvert in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: jupyterlab-pygments in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: testpath in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: bleach in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: async-generator in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: webencodings in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from requests->streamlit) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from requests->streamlit) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from requests->streamlit) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from requests->streamlit) (3.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from tzlocal->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\anisk\anaconda3\envs\geopandas_env\lib\site-packages (from tzlocal->streamlit) (2021.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import geopandas as gpd
import json
import requests
import streamlit as st
from PIL import Image

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
China = pd.read_csv('China.csv')
Bangladesh = pd.read_csv('Bangladesh.csv')
Brazil = pd.read_csv('Brazil.csv')
DRCongo = pd.read_csv('DR Congo.csv')
Egypt = pd.read_csv('Egypt.csv')
Ethiopia = pd.read_csv('Ethiopia.csv')
France = pd.read_csv('France.csv')
Germany = pd.read_csv('Germany.csv')
India = pd.read_csv('India.csv')
Indonasia = pd.read_csv('Indonasia.csv')
Iran = pd.read_csv('Iran.csv')
Italy = pd.read_csv('Italy.csv')
Japan = pd.read_csv('Japan.csv')
Mexico = pd.read_csv('Mexico.csv')
Nigeria = pd.read_csv('Nigeria.csv')
Pakistan = pd.read_csv('Pakistan.csv')
Philippines = pd.read_csv('Philippines.csv')
Russia = pd.read_csv('Russia.csv')
SouthAfrica = pd.read_csv('South Africa.csv')
Tanzania = pd.read_csv('Tanzania.csv')
Thailand = pd.read_csv('Thailand.csv')
Turkey = pd.read_csv('Turkey.csv')
UnitedKingdom = pd.read_csv('United Kingdom.csv')
USA = pd.read_csv('USA.csv')
Vietnam = pd.read_csv('Vietnam.csv')

# %%
#sidebar info
st.set_page_config(layout='wide')
rad = st.sidebar.radio(options=('Home', 'Population', 'Density (P/Km²)', 'Migrants', 'Age', 'map'), label='Select Categorie')
st.sidebar.markdown('#')
st.sidebar.markdown('#')
st.sidebar.subheader('Gemaakt Door:')
st.sidebar.write('• Karlijn Huissen 500889478')
st.sidebar.write('• Aniska Sinnige 500823214')
# Out:
# 2021-11-10 15:53:26.358
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\anisk\anaconda3\envs\geopandas_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
if rad =='Home':
    st.title('Dashboard Population Worldwide')
    img = Image.open("foto.png")
    st.image(img, width=800)

# %%
if rad =='Population':
    st.header('Population')
    st.markdown('#')
    st.subheader('Population of different countries')
    'Onderstaande afbeelding geeft de populatie van een aantal landen weer de jaren 1980, 2000, 2020.'
    
    population800020 = pd.read_csv('PopulationWorld20.00.80.csv')
    
    fig=go.Figure(data=[
    go.Bar(name='1980', x=population800020['ADMIN'], y=population800020['population1980'], marker_color=px.colors.qualitative.Light24[9]),
    go.Bar(name='2000', x=population800020['ADMIN'], y=population800020['populuation2000'], marker_color=px.colors.qualitative.Light24[17]),
    go.Bar(name='2020', x=population800020['ADMIN'], y=population800020['population2020'], marker_color=px.colors.qualitative.Light24[5])])
    
    fig.update_layout(barmode='group', title='Population per Country in 1980,2000,2020',
                  xaxis_title='Country', 
                  yaxis_title='Population number',
                  legend_title='Year')
    st.plotly_chart(fig)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Brazil')
    
    Brazil1=Brazil[['Year', 'Population']]
    fig1 = px.histogram(Brazil1, x='Year', y='Population', nbins=100, title='Population growth of Brazil per year', color_discrete_sequence=['#EEA6FB'])
    st.plotly_chart(fig1)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('China')
    
    China1= China[['Year', 'Population']]
    fig2 = px.histogram(China1, x='Year', y='Population', nbins=100, title='Population growth of China per year', color_discrete_sequence=['#22FFA7'])
    st.plotly_chart(fig2)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Germany')
    
    Germany1= Germany[['Year', 'Population']]
    fig3 = px.histogram(Germany1, x='Year', y='Population', nbins=100, title='Population growth of Germany per year', color_discrete_sequence=['#DC587D'])
    st.plotly_chart(fig3)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Mexico')
    
    Mexico1=Mexico[['Year', 'Population']]
    fig4 = px.histogram(Mexico1, x='Year', y='Population', nbins=100, title='Population growth of Mexico per year', color_discrete_sequence=['#FF9616'])
    st.plotly_chart(fig4)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('South Africa')
    
    SouthAfrica1= SouthAfrica[['Year', 'Population']]
    fig5 = px.histogram(SouthAfrica1, x='Year', y='Population', nbins=100, title='Population growth of South Africa per year', color_discrete_sequence=['#0DF9FF'])
    st.plotly_chart(fig5)

# %%
if rad =='Density (P/Km²)':
    st.header('Density (P/Km²)')
    st.markdown('#')
    'Onderstaande afbeelding geeft de het aantal mensen per vierkante kilometer weer.'
    
    Boxplot_long = pd.read_csv('Boxplot_long.csv')
    
    Country_color_map = {'Brazil': '#EEA6FB', 'China':'#22FFA7', 'Germany':'#DC587D', 'Mexico':'#FF9616', 'South Africa':'#0DF9FF'}
    fig6 = px.box(Boxplot_long, x='Country', y='Density (P/Km²)', color='Country', color_discrete_map=Country_color_map)
    fig6.update_layout(title='Density per Country')
    st.plotly_chart(fig6)

# %%
if rad == 'Migrants':
    st.header('Migrants per country')
    st.markdown('#')
    st.subheader('Brazil')
    
    fig7= px.scatter(Brazil, x='Year', y='Migrants (net)', color_discrete_sequence=['#EEA6FB'], title='Migrants in Brazil', trendline="ols")
    st.plotly_chart(fig7)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('China')
    
    fig8= px.scatter(China, x='Year', y='Migrants (net)', color_discrete_sequence=['#22FFA7'], title='Migrants in China', trendline="ols")
    st.plotly_chart(fig8)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Germany')
    
    fig9= px.scatter(Germany, x='Year', y='Migrants (net)', color_discrete_sequence=['#DC587D'], title='Migrants in Germany', trendline="ols")
    st.plotly_chart(fig9)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Mexico')
    
    fig10= px.scatter(Mexico, x='Year', y='Migrants (net)', color_discrete_sequence=['#FF9616'], title='Migrants in Mexico', trendline="ols")
    st.plotly_chart(fig10)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('South Africa')
    
    fig11= px.scatter(SouthAfrica, x='Year', y='Migrants (net)', color_discrete_sequence=['#0DF9FF'], title='Migrants in South Africa', trendline="ols")
    st.plotly_chart(fig11)

# %%
if rad == 'Age':
    st.header('Average age per country')
    st.markdown('#')
    st.subheader('Brazil')
    
    fig12 = px.scatter(Brazil, x="Year", y="Median Age", trendline="ols", title=' Average age per year in Brazil', color_discrete_sequence=['#EEA6FB'])
    fig12.add_annotation(x=1990, y=24.2, text='R^2 = 0.94')
    st.plotly_chart(fig12)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('China')
    
    fig13 = px.scatter(China, x="Year", y="Median Age", trendline="ols", title=' Average age per year in China', color_discrete_sequence=['#22FFA7'])
    fig13.add_annotation(x=1990, y=27.5, text='R^2 = 0.91')
    st.plotly_chart(fig13)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Germany')
    
    fig14 = px.scatter(Germany, x="Year", y="Median Age", trendline="ols", title=' Average age per year in Germany', color_discrete_sequence=['#DC587D'])
    fig14.add_annotation(x=1990, y=39.5, text='R^2 = 0.93')
    st.plotly_chart(fig14)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('Mexico')
    
    fig15 = px.scatter(Mexico, x="Year", y="Median Age", trendline="ols", title=' Average age per year in Mexico', color_discrete_sequence=['#FF9616'])
    fig15.add_annotation(x=1990, y=21.7, text='R^2 = 0.91')
    st.plotly_chart(fig15)
    ##############################################################################################################
    st.markdown('#')
    st.subheader('South Africa')
    
    fig16 = px.scatter(SouthAfrica, x="Year", y="Median Age", trendline="ols", title=' Average age per year in South Africa', color_discrete_sequence=['#0DF9FF'])
    fig16.add_annotation(x=1990, y=22.2, text='R^2 = 0.81')
    st.plotly_chart(fig16)

# %%
if rad == 'Map':
    st.header('Overview population worldwide')
    st.markdown('#')

    df1= pd.read_csv('PopulationWorld20.00.80.csv')
    df1.rename(columns={'ADMIN':'Country'}, inplace=True)

    df2= gpd.read_file('countries.geojson')
    df2.rename(columns={'ADMIN':'Country'}, inplace=True)

    base_url = 'https://countriesnow.space/api/v0.1/countries/positions'
    response = requests.get(base_url)
    j = response.json()

    df3 = pd.DataFrame(j)
    df4=df3['data'].apply(pd.Series)
    df4.rename(columns={'name':'Country'}, inplace=True)

    df5 = df1.merge(df4, on='Country', how='inner')
    df6 = df5.assign(location=df5[['lat','long']].values.tolist())
    df6.rename(columns={'ADMIN':'Country'}, inplace=True)
    df6.rename(columns={'population1980':'population'}, inplace=True)
    
    fig17 = px.choropleth_mapbox(df6, geojson=df2, color='population', locations='Country', center={"lat": 0, "lon":0 },
                           mapbox_style="carto-positron", zoom=0, featureidkey="properties.Country", hover_name='Country', 
                           hover_data=['long', 'lat'])


    button1 =  dict(method = "update",
                args = [{'z': [ df6['population']]}, {'visible': [ True, False, False]}],
                label = "Population1980")
    button2 =  dict(method = "update",
                args = [{'z': [ df6['populuation2000']]}, {'visible': [ False, True, False]}],
                label = "Population 2000")
    button3 =  dict(method = "update",
                args = [{'z': [ df6['population2020']]}, {'visible': [ False, False, True]}],
                label = "Population 2020")

    fig17.update_layout(margin={"r":0,"t":0,"l":0,"b":0})


    fig17.update_layout({'updatemenus':[{'type': 'dropdown', 'showactive': True, 'active': 0,
                                   'buttons': [button1, button2, button3]}]})

    st.plotly_chart(fig17)
